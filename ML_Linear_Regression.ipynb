# %% [markdown]
# # ML_Linear_Regression

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
from sklearn.linear_model import LinearRegression
# for LR

# %% [markdown]
# # OWN DATA SET FOR LR

# %%
ods=pd.read_csv(r"C:\Users\yarra\OneDrive\Desktop\test.csv")
ods
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
plt.scatter(ods["x"],ods["y"])

# %%
ods.isnull().sum()
# Out:
# x    0
# y    0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression
ownLR=LinearRegression()

# %%
ownLR.fit(ods[["x"]],ods["y"])
ownLR.predict([[10000]])
# Out:
# C:\Users\yarra\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([10142.89174042])

# %% [markdown]
# # DATA SET IN CLASS 1 FOR LR

# %%
ds1=pd.read_csv(r"C:\Users\yarra\OneDrive\Desktop\Data sets\Insurance_LR.csv")
ds1
# Out:
#    Age  Premium
# 0   25    18000
# 1   30    32000
# 2   35    42000
# 3   40    47000
# 4   45    55000

# %%
plt.scatter(ds1["Age"],ds1["Premium"])

# %%
ds1.isnull().sum()
# Out:
# Age        0
# Premium    0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()

# %%
lin_reg.fit(ds1[["Age"]],ds1["Premium"])
# Out:
# LinearRegression()

# %%
lin_reg.predict([[42]])
# Out:
# C:\Users\yarra\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([51260.])

# %%
lin_reg.predict([[67]])
# Out:
# C:\Users\yarra\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([95760.])

# %% [markdown]
# # DATA SET 2 IN CLASS 1 FOR LR
# 1.Multiple inputs

# %%
ds2=pd.read_csv(r"C:\Users\yarra\OneDrive\Desktop\Data sets\House.csv")
ds2
# Out:
#    Area  Bedrooms  Age   Price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %%
ds2.isnull().sum()
# Out:
# Area        0
# Bedrooms    1
# Age         0
# Price       0
# dtype: int64

# %%
ds2.interpolate()
# if floot values can be accepted means
# Out:
#    Area  Bedrooms  Age   Price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       3.5   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %%
import math
var=math.floor(ds2["Bedrooms"].median())

# %%
ds2["Bedrooms"]=ds2["Bedrooms"].fillna(var)

# %%
ds2
# Out:
#    Area  Bedrooms  Age   Price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       3.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %%
ds2.isnull().sum()
# Out:
# Area        0
# Bedrooms    0
# Age         0
# Price       0
# dtype: int64

# %%
plt.plot(ds2["Bedrooms"],ds2["Price"])

# %%
plt.plot(ds2["Area"],ds2["Price"])

# %%
plt.plot(ds2["Age"],ds2["Price"])

# %%
m2=LinearRegression()

# %%
m2.fit(ds2[["Age","Bedrooms","Area"]],ds2["Price"])
# Out:
# LinearRegression()

# %%
m2.predict([[10,6,4500]])
# Out:
# C:\Users\yarra\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([776950.])
