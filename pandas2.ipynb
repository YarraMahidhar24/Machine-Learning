# %%
import pandas as pd

# %% [markdown]
# # Data Frame

# %%
df=pd.read_csv(r"C:\Users\yarra\Downloads\Bank Customer Churn Prediction.csv")
df
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   42       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn'],
#       dtype='object')

# %%
df.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %%
df.head(9)
# Out:
#    customer_id  credit_score  country  gender  age  tenure    balance  \
# 0     15634602           619   France  Female   42       2       0.00
# 1     15647311           608    Spain  Female   41       1   83807.86
# 2     15619304           502   France  Female   42       8  159660.80
# 3     15701354           699   France  Female   39       1       0.00
# 4     15737888           850    Spain  Female   43       2  125510.82
# 5     15574012           645    Spain    Male   44       8  113755.78
# 6     15592531           822   France    Male   50       7       0.00
# 7     15656148           376  Germany  Female   29       4  115046.74
# 8     15792365           501   France    Male   44       4  142051.07
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# ...

# %%
df.tail()
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# 9995                2            1              0          96270.64      0
# 9996                1            1              1         101699.77      0
# 9997                1            0              1          42085.58      1
# 9998                2            1              0          92888.52      1
# 9999                1            1              0          38190.78      0

# %%
df.tail(2)
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# 9998                2            1              0          92888.52      1
# 9999                1            1              0          38190.78      0

# %%
df[100:111]
# Out:
#      customer_id  credit_score  country  gender  age  tenure    balance  \
# 100     15808582           665   France  Female   40       6       0.00
# 101     15743192           623   France  Female   44       6       0.00
# 102     15580146           738   France    Male   31       9   82674.15
# 103     15776605           528    Spain    Male   36       7       0.00
# 104     15804919           670    Spain  Female   65       1       0.00
# 105     15613854           622    Spain  Female   46       4  107073.27
# 106     15599195           582  Germany    Male   32       1   88938.62
# 107     15812878           785  Germany  Female   36       2   99806.85
# 108     15602312           605    Spain    Male   33       5  150092.80
# 109     15744689           479  Germany    Male   35       9   92833.89
# 110     15803526           685  Germany    Male   30       3   90536.81
#
#      products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
df1=pd.read_csv(r"C:\Users\yarra\Downloads\Bank Customer Churn Prediction.csv",skiprows=[1,9996]) # giving index to skip
df1
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15647311           608    Spain  Female   41       1   83807.86
# 1        15619304           502   France  Female   42       8  159660.80
# 2        15701354           699   France  Female   39       1       0.00
# 3        15737888           850    Spain  Female   43       2  125510.82
# 4        15574012           645    Spain    Male   44       8  113755.78
# ...           ...           ...      ...     ...  ...     ...        ...
# 9993     15719294           800   France  Female   29       2       0.00
# 9994     15569892           516   France    Male   35      10   57369.61
# 9995     15584532           709   France  Female   36       7       0.00
# 9996     15682355           772  Germany    Male   42       3   75075.31
# 9997     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
df2=pd.read_csv(r"C:\Users\yarra\Downloads\Bank Customer Churn Prediction.csv",index_col="customer_id") # set in owen indexs
df2
# Out:
#              credit_score  country  gender  age  tenure    balance  \
# customer_id
# 15634602              619   France  Female   42       2       0.00
# 15647311              608    Spain  Female   41       1   83807.86
# 15619304              502   France  Female   42       8  159660.80
# 15701354              699   France  Female   39       1       0.00
# 15737888              850    Spain  Female   43       2  125510.82
# ...                   ...      ...     ...  ...     ...        ...
# 15606229              771   France    Male   39       5       0.00
# 15569892              516   France    Male   35      10   57369.61
# 15584532              709   France  Female   36       7       0.00
# 15682355              772  Germany    Male   42       3   75075.31
# 15628319              792   France  Female   28       4  130142.79
#
#              products_number  credit_card  active_member  estimated_salary  \
# customer_id
# ...

# %%
df3=pd.read_csv(r"C:\Users\yarra\Downloads\Bank Customer Churn Prediction.csv")
df3.sort_index() # index will be sorted
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   42       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
df4=pd.read_csv(r"C:\Users\yarra\Downloads\Bank Customer Churn Prediction.csv")
df4.sort_index(ascending=False) # index in ascending order
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 9999     15628319           792   France  Female   28       4  130142.79
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9997     15584532           709   France  Female   36       7       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9995     15606229           771   France    Male   39       5       0.00
# ...           ...           ...      ...     ...  ...     ...        ...
# 4        15737888           850    Spain  Female   43       2  125510.82
# 3        15701354           699   France  Female   39       1       0.00
# 2        15619304           502   France  Female   42       8  159660.80
# 1        15647311           608    Spain  Female   41       1   83807.86
# 0        15634602           619   France  Female   42       2       0.00
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
df5=pd.read_csv(r"C:\Users\yarra\Downloads\Bank Customer Churn Prediction.csv")
print(df5["age"][1]) # value printing
# Out:
# 41

# %%
df6=pd.read_csv(r"C:\Users\yarra\Downloads\Bank Customer Churn Prediction.csv")
df6.loc[2,"age"]=99 # assiging
df6
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   99       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
df7=df6.loc[[0,1,2,3],["age","gender","country"]] # taking the required part by indexs and col_names
df7
# Out:
#    age  gender country
# 0   42  Female  France
# 1   41  Female   Spain
# 2   99  Female  France
# 3   39  Female  France

# %%
df8=df6.loc[[0,1,2,3],:] # taking the required indexs and  all columns
df8
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   99       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0

# %%
df9=df6.loc[:,["customer_id","credit_score","country","gender","age","balance"]] # taking the all indexs and required  columns
df9
# Out:
#       customer_id  credit_score  country  gender  age    balance
# 0        15634602           619   France  Female   42       0.00
# 1        15647311           608    Spain  Female   41   83807.86
# 2        15619304           502   France  Female   99  159660.80
# 3        15701354           699   France  Female   39       0.00
# 4        15737888           850    Spain  Female   43  125510.82
# ...           ...           ...      ...     ...  ...        ...
# 9995     15606229           771   France    Male   39       0.00
# 9996     15569892           516   France    Male   35   57369.61
# 9997     15584532           709   France  Female   36       0.00
# 9998     15682355           772  Germany    Male   42   75075.31
# 9999     15628319           792   France  Female   28  130142.79
#
# [10000 rows x 6 columns]

# %%
df10=df6.iloc[199,2] # idex and colum no to get data
df10
# Out:
# 'France'

# %%
df11=df6.iloc[:,0:6] # all idex and range ofcolum no to get datas
df11
# Out:
#       customer_id  credit_score  country  gender  age  tenure
# 0        15634602           619   France  Female   42       2
# 1        15647311           608    Spain  Female   41       1
# 2        15619304           502   France  Female   99       8
# 3        15701354           699   France  Female   39       1
# 4        15737888           850    Spain  Female   43       2
# ...           ...           ...      ...     ...  ...     ...
# 9995     15606229           771   France    Male   39       5
# 9996     15569892           516   France    Male   35      10
# 9997     15584532           709   France  Female   36       7
# 9998     15682355           772  Germany    Male   42       3
# 9999     15628319           792   France  Female   28       4
#
# [10000 rows x 6 columns]

# %%
df12=df6.iloc[0:6,:] # range fo rows and al colums
df12
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   99       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
# 5     15574012           645   Spain    Male   44       8  113755.78
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0
# ...

# %%
df13=pd.read_csv(r"C:\Users\yarra\Downloads\Bank Customer Churn Prediction.csv")
df13.drop(2) # droping index 2
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# 5        15574012           645    Spain    Male   44       8  113755.78
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
df14=pd.read_csv(r"C:\Users\yarra\Downloads\Bank Customer Churn Prediction.csv")
df14.drop("gender",axis=1) # Removing Colum by colum name
# Out:
#       customer_id  credit_score  country  age  tenure    balance  \
# 0        15634602           619   France   42       2       0.00
# 1        15647311           608    Spain   41       1   83807.86
# 2        15619304           502   France   42       8  159660.80
# 3        15701354           699   France   39       1       0.00
# 4        15737888           850    Spain   43       2  125510.82
# ...           ...           ...      ...  ...     ...        ...
# 9995     15606229           771   France   39       5       0.00
# 9996     15569892           516   France   35      10   57369.61
# 9997     15584532           709   France   36       7       0.00
# 9998     15682355           772  Germany   42       3   75075.31
# 9999     15628319           792   France   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# 0                   1            1              1         101348.88      1
# ...

# %%
df15=pd.read_csv(r"C:\Users\yarra\Downloads\Bank Customer Churn Prediction.csv")
df15.drop(9999,axis=0)  # Removing row by index
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   42       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9994     15719294           800   France  Female   29       2       0.00
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
df16=pd.read_csv(r"C:\Users\yarra\Downloads\Train.csv")
df16
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
df16.isnull().sum()  # Giving NA values count for colums
# Out:
# ID                   0
# Gender               0
# Ever_Married       140
# Age                  0
# Graduated           78
# Profession         124
# Work_Experience    829
# Spending_Score       0
# Family_Size        335
# Var_1               76
# Segmentation         0
# dtype: int64

# %%
df16.dropna() # Droping na values from the Table by removing row Temp not permenent
# Out:
#           ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0     462809    Male           No   22        No  Healthcare              1.0
# 2     466315  Female          Yes   67       Yes    Engineer              1.0
# 3     461735    Male          Yes   67       Yes      Lawyer              0.0
# 5     461319    Male          Yes   56        No      Artist              0.0
# 6     460156    Male           No   32       Yes  Healthcare              1.0
# ...      ...     ...          ...  ...       ...         ...              ...
# 8062  463002    Male          Yes   41       Yes      Artist              0.0
# 8064  464685    Male           No   35        No   Executive              3.0
# 8065  465406  Female           No   33       Yes  Healthcare              1.0
# 8066  467299  Female           No   27       Yes  Healthcare              1.0
# 8067  461879    Male          Yes   37       Yes   Executive              0.0
#
# ...

# %%
df16.dropna(axis=0) # Droping na values from the Table by removing row Temp not permenent
# Out:
#           ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0     462809    Male           No   22        No  Healthcare              1.0
# 2     466315  Female          Yes   67       Yes    Engineer              1.0
# 3     461735    Male          Yes   67       Yes      Lawyer              0.0
# 5     461319    Male          Yes   56        No      Artist              0.0
# 6     460156    Male           No   32       Yes  Healthcare              1.0
# ...      ...     ...          ...  ...       ...         ...              ...
# 8062  463002    Male          Yes   41       Yes      Artist              0.0
# 8064  464685    Male           No   35        No   Executive              3.0
# 8065  465406  Female           No   33       Yes  Healthcare              1.0
# 8066  467299  Female           No   27       Yes  Healthcare              1.0
# 8067  461879    Male          Yes   37       Yes   Executive              0.0
#
# ...

# %%
df16.dropna(axis=1) # Droping na values from the Table by removing colums Temp not permenent
# Out:
#           ID  Gender  Age Spending_Score Segmentation
# 0     462809    Male   22            Low            D
# 1     462643  Female   38        Average            A
# 2     466315  Female   67            Low            B
# 3     461735    Male   67           High            B
# 4     462669  Female   40           High            A
# ...      ...     ...  ...            ...          ...
# 8063  464018    Male   22            Low            D
# 8064  464685    Male   35            Low            D
# 8065  465406  Female   33            Low            D
# 8066  467299  Female   27            Low            B
# 8067  461879    Male   37        Average            B
#
# [8068 rows x 5 columns]

# %%
df16.dropna(axis=0,inplace=True)# Droping na values from the Table by removing colums permenently data stored or changed
df16
# Out:
#           ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0     462809    Male           No   22        No  Healthcare              1.0
# 2     466315  Female          Yes   67       Yes    Engineer              1.0
# 3     461735    Male          Yes   67       Yes      Lawyer              0.0
# 5     461319    Male          Yes   56        No      Artist              0.0
# 6     460156    Male           No   32       Yes  Healthcare              1.0
# ...      ...     ...          ...  ...       ...         ...              ...
# 8062  463002    Male          Yes   41       Yes      Artist              0.0
# 8064  464685    Male           No   35        No   Executive              3.0
# 8065  465406  Female           No   33       Yes  Healthcare              1.0
# 8066  467299  Female           No   27       Yes  Healthcare              1.0
# 8067  461879    Male          Yes   37       Yes   Executive              0.0
#
# ...

# %%
df17=pd.read_csv(r"C:\Users\yarra\Downloads\Train.csv")
df17
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
df17.dropna(how="any") # if any one colume in row is Nan the row is deleted
# Out:
#           ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0     462809    Male           No   22        No  Healthcare              1.0
# 2     466315  Female          Yes   67       Yes    Engineer              1.0
# 3     461735    Male          Yes   67       Yes      Lawyer              0.0
# 5     461319    Male          Yes   56        No      Artist              0.0
# 6     460156    Male           No   32       Yes  Healthcare              1.0
# ...      ...     ...          ...  ...       ...         ...              ...
# 8062  463002    Male          Yes   41       Yes      Artist              0.0
# 8064  464685    Male           No   35        No   Executive              3.0
# 8065  465406  Female           No   33       Yes  Healthcare              1.0
# 8066  467299  Female           No   27       Yes  Healthcare              1.0
# 8067  461879    Male          Yes   37       Yes   Executive              0.0
#
# ...

# %%
df18=pd.read_csv(r"C:\Users\yarra\Downloads\Train.csv")
df18.dropna(how="all") # if all colum values are Nan the row is removed
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
df19=pd.read_csv(r"C:\Users\yarra\Downloads\Train.csv")
df19.dropna(subset=["Gender","Age","Profession"]) # if specific colums values are Nan the row is removed
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8062  463002    Male          Yes   41       Yes         Artist
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
df19["Age"].isnull().sum() # Counts the coulum specific Nans
# Out:
# 0

# %% [markdown]
# # Filling NULL Values

# %%
ds1=pd.read_csv(r"C:\Users\yarra\Downloads\Train.csv")
ds1
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
ds1.fillna("python") # filling NaN values with The given data 
# inplace = True will make data permenent
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No         python
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#      Work_Experience Spending_Score Family_Size  Var_1 Segmentation
# 0                1.0            Low         4.0  Cat_4            D
# ...

# %%
ds2=pd.read_csv(r"C:\Users\yarra\Downloads\Train.csv")
ds2.fillna({"Work_Experience":2},inplace=True) # Setting the specific colum values to be ex2
ds2
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %% [markdown]
# # ds.interpolate(inplace=True)

# %%
# this will make numerical value columes na values to the meadion
